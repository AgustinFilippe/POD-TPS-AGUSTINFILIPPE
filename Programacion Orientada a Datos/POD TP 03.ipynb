# %% [markdown]
# *   **Año:** 2024
# *   **Alumno/a:** Flippe Agustin
# *   **Legajo:** 1207540

# %% [markdown]
# # Pandas
# A continuación, cada celda va a pedir algo distinto. Por favor, realizarlo con la menor cantidad de lineas posibles y con NumPy.

# %% [markdown]
# Importar `pandas` con el alias `pd` e imprimir la versión instalada.

# %%
#Escribir el codigo para responder la pregunta en esta celda
import pandas as pd

# %% [markdown]
# Crear la siguiente tabla como un dataframe de Pandas donde cada linea represente un diccionario.
#
# | _Index_ | **nombre**       | **edad** | **dni**  |
# |---------|------------------|----------|----------|
# | 9       | Brown, James     | 43       | 30123444 |
# | 3       | Hamkel, Louis V. | 29       | 44555666 |
# | 7       | Baptista, Carlos | 28       | 43120111 |

# %%
#Escribir el codigo para responder la pregunta en esta celda
lista_df = [
    {'nombre':'Brown, James', 'edad' : 43, 'dni': '30123444'},
    {'nombre':'Hamkel, Louis V.', 'edad' : 29, 'dni': '44555666'},
    {'nombre':'Baptista, Carlos', 'edad' : 28, 'dni': '43120111'}
]
df = pd.DataFrame(lista_df, index=[9, 3, 7])
df
# Out:
#              nombre  edad       dni
# 9      Brown, James    43  30123444
# 3  Hamkel, Louis V.    29  44555666
# 7  Baptista, Carlos    28  43120111

# %% [markdown]
# Crear la siguiente tabla como un dataframe de Pandas donde todas las lineas esten dentro de un solo diccionario.
#
# | _Index_ | **nombre**       | **edad** | **dni**  |
# |---------|------------------|----------|----------|
# | 9       | Brown, James     | 43       | 30123444 |
# | 3       | Hamkel, Louis V. | 29       | 44555666 |
# | 7       | Baptista, Carlos | 28       | 43120111 |

# %%
#Escribir el codigo para responder la pregunta en esta celda
dicc = {
    'nombre' : ['Brown, James', 'Hamkel, Louis V.', 'Baptista, Carlos'],
    'edad' : [43, 29, 28],
    'dni' : [30123444, 44555666, 43120111],
}
df = pd.DataFrame(dicc, index= [9, 3, 7])
df
# Out:
#              nombre  edad       dni
# 9      Brown, James    43  30123444
# 3  Hamkel, Louis V.    29  44555666
# 7  Baptista, Carlos    28  43120111

# %% [markdown]
# Crear la siguiente tabla como un dataframe de Pandas donde se usen unicamente listas.
#
# | _Index_ | **nombre**       | **edad** | **dni**  |
# |---------|------------------|----------|----------|
# | 9       | Brown, James     | 43       | 30123444 |
# | 3       | Hamkel, Louis V. | 29       | 44555666 |
# | 7       | Baptista, Carlos | 28       | 43120111 |

# %%
#Escribir el codigo para responder la pregunta en esta celda
columns = ['nombre', 'edad', 'dni']
lista_df = [
    ['Brown, James', 43, '30123444'],
    ['Hamkel, Louis V.', 29, '44555666'],
    ['Baptista, Carlos', 28, '43120111']
]

df_lista = pd.DataFrame(data = lista_df, columns = columns, index=[9, 3, 7])
df_lista
# Out:
#              nombre  edad       dni
# 9      Brown, James    43  30123444
# 3  Hamkel, Louis V.    29  44555666
# 7  Baptista, Carlos    28  43120111

# %% [markdown]
# Crear la siguiente tabla como un dataframe de Pandas donde se usen unicamente `Series`.
#
# | _Index_ | **nombre**       | **edad** | **dni**  |
# |---------|------------------|----------|----------|
# | 9       | Brown, James     | 43       | 30123444 |
# | 3       | Hamkel, Louis V. | 29       | 44555666 |
# | 7       | Baptista, Carlos | 28       | 43120111 |

# %%
#Escribir el codigo para responder la pregunta en esta celda
columna_nombre = pd.Series(['Brown, James', 'Hamkel, Louis V.', 'Baptista, Carlos'])
columna_edad = pd.Series([43, 29, 28])
columna_dni = pd.Series(['30123444', '44555666', '43120111'])
df_series = pd.DataFrame({'nombre': columna_nombre, 'edad': columna_edad, 'dni': columna_dni})
df_series.index = [9, 3, 7]
df_series
# Out:
#              nombre  edad       dni
# 9      Brown, James    43  30123444
# 3  Hamkel, Louis V.    29  44555666
# 7  Baptista, Carlos    28  43120111

# %% [markdown]
# Reutilice cualquiera de los dataframe hechos anteriormente pero agregue la columna `fecha` con el tipo de dato relacionado a fechas.
#
# | _Index_ | **nombre**       | **edad** | **dni**  | **fecha**  |
# |---------|------------------|----------|----------|------------|
# | 9       | Brown, James     | 43       | 30123444 | 12/08/1981 |
# | 3       | Hamkel, Louis V. | 29       | 44555666 | 10/04/1995 |
# | 7       | Baptista, Carlos | 28       | 43120111 | 28/05/1996 |

# %%
#Escribir el codigo para responder la pregunta en esta celda
dicc = {
    'nombre' : ['Brown, James', 'Hamkel, Louis V.', 'Baptista, Carlos'],
    'edad' : [43, 29, 28],
    'dni' : [30123444, 44555666, 43120111],
    'fecha' : ['12/08/1981', '10/04/1995', '28/05/1996']
}
df = pd.DataFrame(dicc, index= [9, 3, 7])
df['fecha'].apply(lambda x: pd.to_datetime(df['fecha'], format='%d/%m/%Y'))
df
# Out:
#              nombre  edad       dni       fecha
# 9      Brown, James    43  30123444  12/08/1981
# 3  Hamkel, Louis V.    29  44555666  10/04/1995
# 7  Baptista, Carlos    28  43120111  28/05/1996

# %% [markdown]
# Ejecute la siguiente celda. Se va a descargar un archivo llamado `u.user`.

# %%
# !wget https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user
# Out:
# --2024-11-18 22:21:19--  https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22667 (22K) [text/plain]
# Saving to: ‘u.user’
#
# u.user              100%[===================>]  22.14K  --.-KB/s    in 0s
#
# 2024-11-18 22:21:19 (93.1 MB/s) - ‘u.user’ saved [22667/22667]

# %% [markdown]
# Lea el archivo con pandas y muestre las primeras 5 filas.

# %%
#Escribir el codigo para responder la pregunta en esta celda

# %%
data = pd.read_csv('u.user', sep='|')

# %% [markdown]
# Utilice la columna `user_id` como indice y saque dicha columna del dataframe

# %%
#Escribir el codigo para responder la pregunta en esta celda
df = pd.DataFrame(data, index=data['user_id'])

# %% [markdown]
# ¿Cuantas categorias de trabajos hay?

# %%
#Escribir el codigo para responder la pregunta en esta celda
len(df.occupation.value_counts())
# Out:
# 21

# %% [markdown]
#  Reporte el porcentaje de personas que tiene cada ocupación.

# %%
#Escribir el codigo para responder la pregunta en esta celda
df.occupation.value_counts(normalize=True)
# Out:
# occupation
# student          0.208068
# other            0.111465
# educator         0.100849
# administrator    0.083864
# engineer         0.071125
# programmer       0.070064
# librarian        0.054140
# writer           0.047771
# executive        0.033970
# scientist        0.032909
# artist           0.029724
# technician       0.027601
# marketing        0.027601
# entertainment    0.019108
# healthcare       0.016985
# retired          0.014862
# lawyer           0.012739
# salesman         0.012739
# none             0.009554
# homemaker        0.007431
# doctor           0.007431
# Name: proportion, dtype: float64

# %% [markdown]
# Reporte el promedio de edad de los estudiantes usando indexeo booleano.

# %%
#Escribir el codigo para responder la pregunta en esta celda
datos_estudiantes = df[df['occupation'] == 'student']
datos_estudiantes['age'].mean()
# Out:
# 22.081632653061224

# %% [markdown]
# Mostrar, con una sola linea y sin importar `matplotlib`, un histograma de las edades de las personas que son administradores.

# %%
#Escribir el codigo para responder la pregunta en esta celda

# %% [markdown]
# Reemplace, sin usar `for`, en la columna `gender` `F` por `female` y `M` por `male`.

# %%
#Escribir el codigo para responder la pregunta en esta celda
df['gender'].replace('M', 'male', inplace=True)
df
# Out:
# <ipython-input-15-bef6892ddf7e>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].replace('M', 'male', inplace=True)
#          user_id   age gender     occupation zip_code
# user_id
# 1            2.0  53.0      F          other    94043
# 2            3.0  23.0   male         writer    32067
# 3            4.0  24.0   male     technician    43537
# 4            5.0  33.0      F          other    15213
# 5            6.0  42.0   male      executive    98101
# ...          ...   ...    ...            ...      ...
# 939        940.0  32.0   male  administrator    02215
# 940        941.0  20.0   male        student    97229
# 941        942.0  48.0      F      librarian    78209
# 942        943.0  22.0   male        student    77841
# 943          NaN   NaN    NaN            NaN      NaN
#
# [943 rows x 5 columns]

# %% [markdown]
# # Yahoo! Finance

# %% [markdown]
# Vamos a analizar acciones. La siguiente linea accede a Yahoo Finance y devuelve un DataFrame con los valores de la acción cada dia desde el 1980.

# %%
import yfinance as yf
dataframe = yf.download('AAPL', start="1980-01-01", end="2030-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ¿Cual es el registro mas viejo? Imprimirlo.

# %%
dataframe.index.min()
# Out:
# Timestamp('1980-12-12 00:00:00+0000', tz='UTC')

# %%
dataframe.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             (    'Close', 'AAPL'),
#             (     'High', 'AAPL'),
#             (      'Low', 'AAPL'),
#             (     'Open', 'AAPL'),
#             (   'Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %% [markdown]
# Cree la columna `Average` tal que
#
# $$Average =  \frac{High-Low}{2}$$
#
# y muestre con un histograma dicha columna.

# %%
#Escribir el codigo para responder la pregunta en esta celda
dataframe['average'] = (dataframe['High'] - dataframe['Low']) / 2
#Escribir el codigo para responder la pregunta en esta celda
import matplotlib.pyplot as plt

plt.hist(dataframe['average'], edgecolor='black')
plt.show()

# %% [markdown]
# Con `matplotlib`, muestre como `Average` fue evolucionando *al final de cada año*.

# %%
dataframe.head()
# Out:
# Price                     Adj Close     Close      High       Low      Open  \
# Ticker                         AAPL      AAPL      AAPL      AAPL      AAPL
# Date
# 1980-12-12 00:00:00+00:00  0.098834  0.128348  0.128906  0.128348  0.128348
# 1980-12-15 00:00:00+00:00  0.093678  0.121652  0.122210  0.121652  0.122210
# 1980-12-16 00:00:00+00:00  0.086802  0.112723  0.113281  0.112723  0.113281
# 1980-12-17 00:00:00+00:00  0.088951  0.115513  0.116071  0.115513  0.115513
# 1980-12-18 00:00:00+00:00  0.091530  0.118862  0.119420  0.118862  0.118862
#
# Price                         Volume   average
# Ticker                          AAPL
# Date
# 1980-12-12 00:00:00+00:00  469033600  0.000279
# 1980-12-15 00:00:00+00:00  175884800  0.000279
# 1980-12-16 00:00:00+00:00  105728000  0.000279
# 1980-12-17 00:00:00+00:00   86441600  0.000279
# 1980-12-18 00:00:00+00:00   73449600  0.000279

# %%
dataframe['Date'] = pd.to_datetime(dataframe.index)
dataframe['Year'] = dataframe['Date'].dt.year
dataframe['Month'] = dataframe['Date'].dt.month
dataframe['Day'] = dataframe['Date'].dt.day
ultimo_dia = dataframe[(dataframe['Day'] == 31) & (dataframe['Month'] == 12)]

plt.plot(ultimo_dia.index, ultimo_dia.values, color='blue')
plt.show()

# %% [markdown]
# Muestre con un gráfico de barras, como el volumen fue cambiando *año a año*.

# %%
#Escribir el codigo para responder la pregunta en esta celda
dataframe['Date'] = pd.to_datetime(dataframe.index)
dataframe['Year'] = dataframe['Date'].dt.year
yearly_average = dataframe.groupby('Year')['average'].mean()

plt.plot(yearly_average.index, yearly_average.values)
plt.show()

# %% [markdown]
# # Cancelaciones y Delays de vuelos del 2015

# %% [markdown]
# Creese una cuenta en Kaggle e importe los archivos del dataset del siguiente link: https://www.kaggle.com/datasets/usdot/flight-delays. Cree los dataframes `airlines`, `airports`, y `flights` apartir de esos archivos.

# %%
#Escribir el codigo para responder la pregunta en esta celda
# !kaggle datasets download -d usdot/flight-delays
# !unzip flight-delays.zip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/usdot/flight-delays
# License(s): CC0-1.0
# flight-delays.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  flight-delays.zip
#   inflating: airlines.csv
#   inflating: airports.csv
#   inflating: flights.csv

# %%
import pandas as pd
import numpy as np

# %%
data_airlines = pd.read_csv('airlines.csv')
data_flights = pd.read_csv('flights.csv')
data_airports = pd.read_csv('airports.csv')
# Out:
# <ipython-input-16-591acfa5d1df>:2: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_flights = pd.read_csv('flights.csv')

# %%
#Escribir el codigo para responder la pregunta en esta celda
data_airlines
# Out:
#    IATA_CODE                       AIRLINE
# 0         UA         United Air Lines Inc.
# 1         AA        American Airlines Inc.
# 2         US               US Airways Inc.
# 3         F9        Frontier Airlines Inc.
# 4         B6               JetBlue Airways
# 5         OO         Skywest Airlines Inc.
# 6         AS          Alaska Airlines Inc.
# 7         NK              Spirit Air Lines
# 8         WN        Southwest Airlines Co.
# 9         DL          Delta Air Lines Inc.
# 10        EV   Atlantic Southeast Airlines
# 11        HA        Hawaiian Airlines Inc.
# 12        MQ  American Eagle Airlines Inc.
# 13        VX                Virgin America

# %%
data_airports
# Out:
#     IATA_CODE                              AIRPORT  \
# 0         ABE  Lehigh Valley International Airport
# 1         ABI             Abilene Regional Airport
# 2         ABQ    Albuquerque International Sunport
# 3         ABR            Aberdeen Regional Airport
# 4         ABY   Southwest Georgia Regional Airport
# ..        ...                                  ...
# 317       WRG                     Wrangell Airport
# 318       WYS               Westerly State Airport
# 319       XNA  Northwest Arkansas Regional Airport
# 320       YAK                      Yakutat Airport
# 321       YUM           Yuma International Airport
#
#                                CITY STATE COUNTRY  LATITUDE  LONGITUDE
# 0                         Allentown    PA     USA  40.65236  -75.44040
# 1                           Abilene    TX     USA  32.41132  -99.68190
# 2                       Albuquerque    NM     USA  35.04022 -106.60919
# 3                          Aberdeen    SD     USA  45.44906  -98.42183
# 4                            Albany    GA     USA  31.53552  -84.19447
# ..                              ...   ...     ...       ...        ...
# 317                        Wrangell    AK     USA  56.48433 -132.36982
# 318                West Yellowstone    MT     USA  44.68840 -111.11764
# 319  Fayetteville/Springdale/Rogers    AR     USA  36.28187  -94.30681
# 320                         Yakutat    AK     USA  59.50336 -139.66023
# 321                            Yuma    AZ     USA  32.65658 -114.60597
#
# [322 rows x 7 columns]

# %%
data_flights
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 0                  ANC                 SEA                    5  ...
# 1                  LAX                 PBI                   10  ...
# 2                  SFO                 CLT                   20  ...
# 3                  LAX                 MIA                   20  ...
# 4                  SEA                 ANC                   25  ...
# ...                ...                 ...                  ...  ...
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# 0               408.0          -22.0         0          0
# 1               741.0           -9.0         0          0
# 2               811.0            5.0         0          0
# 3               756.0           -9.0         0          0
# 4               259.0          -21.0         0          0
# ...               ...            ...       ...        ...
# 5819074         753.0          -26.0         0          0
# 5819075         430.0          -16.0         0          0
# 5819076         432.0           -8.0         0          0
# 5819077         330.0          -10.0         0          0
# 5819078         442.0            2.0         0          0
#
#          CANCELLATION_REASON  AIR_SYSTEM_DELAY  SECURITY_DELAY  AIRLINE_DELAY  \
# 0                        NaN               NaN             NaN            NaN
# 1                        NaN               NaN             NaN            NaN
# 2                        NaN               NaN             NaN            NaN
# 3                        NaN               NaN             NaN            NaN
# 4                        NaN               NaN             NaN            NaN
# ...                      ...               ...             ...            ...
# 5819074                  NaN               NaN             NaN            NaN
# 5819075                  NaN               NaN             NaN            NaN
# 5819076                  NaN               NaN             NaN            NaN
# 5819077                  NaN               NaN             NaN            NaN
# 5819078                  NaN               NaN             NaN            NaN
#
#          LATE_AIRCRAFT_DELAY  WEATHER_DELAY
# 0                        NaN            NaN
# 1                        NaN            NaN
# 2                        NaN            NaN
# 3                        NaN            NaN
# 4                        NaN            NaN
# ...                      ...            ...
# 5819074                  NaN            NaN
# 5819075                  NaN            NaN
# 5819076                  NaN            NaN
# 5819077                  NaN            NaN
# 5819078                  NaN            NaN
#
# [5819079 rows x 31 columns]

# %%
df = pd.merge(data_flights, data_airlines, left_on='AIRLINE', right_on='IATA_CODE', how='left')

# %%
df = pd.merge(df, data_airports, left_on='ORIGIN_AIRPORT', right_on='IATA_CODE', how='left')

# %%
df
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4        AS             98      N407AS
# 1        2015      1    1            4        AA           2336      N3KUAA
# 2        2015      1    1            4        US            840      N171US
# 3        2015      1    1            4        AA            258      N3HYAA
# 4        2015      1    1            4        AS            135      N527AS
# ...       ...    ...  ...          ...       ...            ...         ...
# 5819074  2015     12   31            4        B6            688      N657JB
# 5819075  2015     12   31            4        B6            745      N828JB
# 5819076  2015     12   31            4        B6           1503      N913JB
# 5819077  2015     12   31            4        B6            333      N527JB
# 5819078  2015     12   31            4        B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 0                  ANC                 SEA                    5  ...
# 1                  LAX                 PBI                   10  ...
# 2                  SFO                 CLT                   20  ...
# 3                  LAX                 MIA                   20  ...
# 4                  SEA                 ANC                   25  ...
# ...                ...                 ...                  ...  ...
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          WEATHER_DELAY  IATA_CODE_x               AIRLINE_y  IATA_CODE_y  \
# 0                  NaN           AS    Alaska Airlines Inc.          ANC
# 1                  NaN           AA  American Airlines Inc.          LAX
# 2                  NaN           US         US Airways Inc.          SFO
# 3                  NaN           AA  American Airlines Inc.          LAX
# 4                  NaN           AS    Alaska Airlines Inc.          SEA
# ...                ...          ...                     ...          ...
# 5819074            NaN           B6         JetBlue Airways          LAX
# 5819075            NaN           B6         JetBlue Airways          JFK
# 5819076            NaN           B6         JetBlue Airways          JFK
# 5819077            NaN           B6         JetBlue Airways          MCO
# 5819078            NaN           B6         JetBlue Airways          JFK
#
#                                                    AIRPORT           CITY  \
# 0              Ted Stevens Anchorage International Airport      Anchorage
# 1                        Los Angeles International Airport    Los Angeles
# 2                      San Francisco International Airport  San Francisco
# 3                        Los Angeles International Airport    Los Angeles
# 4                     Seattle-Tacoma International Airport        Seattle
# ...                                                    ...            ...
# 5819074                  Los Angeles International Airport    Los Angeles
# 5819075  John F. Kennedy International Airport (New Yor...       New York
# 5819076  John F. Kennedy International Airport (New Yor...       New York
# 5819077                      Orlando International Airport        Orlando
# 5819078  John F. Kennedy International Airport (New Yor...       New York
#
#          STATE  COUNTRY  LATITUDE  LONGITUDE
# 0           AK      USA  61.17432 -149.99619
# 1           CA      USA  33.94254 -118.40807
# 2           CA      USA  37.61900 -122.37484
# 3           CA      USA  33.94254 -118.40807
# 4           WA      USA  47.44898 -122.30931
# ...        ...      ...       ...        ...
# 5819074     CA      USA  33.94254 -118.40807
# 5819075     NY      USA  40.63975  -73.77893
# 5819076     NY      USA  40.63975  -73.77893
# 5819077     FL      USA  28.42889  -81.31603
# 5819078     NY      USA  40.63975  -73.77893
#
# [5819079 rows x 40 columns]

# %% [markdown]
# Combine (*join*) las tablas `airlines`, `airports`, y `flights` en una sola tabla.

# %% [markdown]
# Lo hice arriba

# %% [markdown]
# ¿Cuantos vuelos fueron al aeropuerto JFK?

# %%
#Escribir el codigo para responder la pregunta en esta celda
(df['DESTINATION_AIRPORT'] == 'JFK').sum()
# Out:
# 93809

# %% [markdown]
# ¿Cuantos vuelos hizo la aerolinea AA?

# %%
#Escribir el codigo para responder la pregunta en esta celda
(df['AIRLINE_x'] == 'AA').sum()
# Out:
# 725984

# %% [markdown]
# ¿Que aerolineas (las primeras 5) tuvo la menor cantidad de vuelos con atrasos? Imprimirlas.

# %%
#Escribir el codigo para responder la pregunta en esta celda
df['AIRLINE_x'].value_counts()
# Out:
# AIRLINE_x
# WN    1261855
# DL     875881
# AA     725984
# OO     588353
# EV     571977
# UA     515723
# MQ     294632
# B6     267048
# US     198715
# AS     172521
# NK     117379
# F9      90836
# HA      76272
# VX      61903
# Name: count, dtype: int64

# %% [markdown]
# ¿Que aerolineas (las primeras 5) tuvo la mayor cantidad de vuelos con atrasos? Imprimirlas.

# %%
#Escribir el codigo para responder la pregunta en esta celda
df['AIRLINE_x'].value_counts()
# Out:
# AIRLINE_x
# WN    1261855
# DL     875881
# AA     725984
# OO     588353
# EV     571977
# UA     515723
# MQ     294632
# B6     267048
# US     198715
# AS     172521
# NK     117379
# F9      90836
# HA      76272
# VX      61903
# Name: count, dtype: int64

# %% [markdown]
# Haga un resumen de las razones por la cual los vuelos se atrasan.

# %%
#Escribir el codigo para responder la pregunta en esta celda

# %% [markdown]
# Compruebe si hay columnas con celdas vacias.

# %%
#Escribir el codigo para responder la pregunta en esta celda
df.isnull().sum()
# Out:
# YEAR                         0
# MONTH                        0
# DAY                          0
# DAY_OF_WEEK                  0
# AIRLINE_x                    0
# FLIGHT_NUMBER                0
# TAIL_NUMBER              14721
# ORIGIN_AIRPORT               0
# DESTINATION_AIRPORT          0
# SCHEDULED_DEPARTURE          0
# DEPARTURE_TIME           86153
# DEPARTURE_DELAY          86153
# TAXI_OUT                 89047
# WHEELS_OFF               89047
# SCHEDULED_TIME               6
# ELAPSED_TIME            105071
# AIR_TIME                105071
# DISTANCE                     0
# WHEELS_ON                92513
# TAXI_IN                  92513
# SCHEDULED_ARRIVAL            0
# ARRIVAL_TIME             92513
# ARRIVAL_DELAY           105071
# DIVERTED                     0
# CANCELLED                    0
# CANCELLATION_REASON    5729195
# AIR_SYSTEM_DELAY       4755640
# SECURITY_DELAY         4755640
# AIRLINE_DELAY          4755640
# LATE_AIRCRAFT_DELAY    4755640
# WEATHER_DELAY          4755640
# IATA_CODE_x                  0
# AIRLINE_y                    0
# IATA_CODE_y             486165
# AIRPORT                 486165
# CITY                    486165
# STATE                   486165
# COUNTRY                 486165
# LATITUDE                490770
# LONGITUDE               490770
# dtype: int64

# %% [markdown]
# Haga una imputación de datos COMPLETA del dataframe. Pueden escojer cualquier estrategia y no necesariamente todas las columnas deben seguir la misma estrategia.

# %%
#Escribir el codigo para responder la pregunta en esta celda
df.fillna(method='ffill', inplace=True)
# Out:
# <ipython-input-58-cae344639d95>:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill')
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE_x  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4        AS             98      N407AS
# 1        2015      1    1            4        AA           2336      N3KUAA
# 2        2015      1    1            4        US            840      N171US
# 3        2015      1    1            4        AA            258      N3HYAA
# 4        2015      1    1            4        AS            135      N527AS
# ...       ...    ...  ...          ...       ...            ...         ...
# 5819074  2015     12   31            4        B6            688      N657JB
# 5819075  2015     12   31            4        B6            745      N828JB
# 5819076  2015     12   31            4        B6           1503      N913JB
# 5819077  2015     12   31            4        B6            333      N527JB
# 5819078  2015     12   31            4        B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 0                  ANC                 SEA                    5  ...
# 1                  LAX                 PBI                   10  ...
# 2                  SFO                 CLT                   20  ...
# 3                  LAX                 MIA                   20  ...
# 4                  SEA                 ANC                   25  ...
# ...                ...                 ...                  ...  ...
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          WEATHER_DELAY  IATA_CODE_x               AIRLINE_y  IATA_CODE_y  \
# 0                  NaN           AS    Alaska Airlines Inc.          ANC
# 1                  NaN           AA  American Airlines Inc.          LAX
# 2                  NaN           US         US Airways Inc.          SFO
# 3                  NaN           AA  American Airlines Inc.          LAX
# 4                  NaN           AS    Alaska Airlines Inc.          SEA
# ...                ...          ...                     ...          ...
# 5819074            0.0           B6         JetBlue Airways          LAX
# 5819075            0.0           B6         JetBlue Airways          JFK
# 5819076            0.0           B6         JetBlue Airways          JFK
# 5819077            0.0           B6         JetBlue Airways          MCO
# 5819078            0.0           B6         JetBlue Airways          JFK
#
#                                                    AIRPORT           CITY  \
# 0              Ted Stevens Anchorage International Airport      Anchorage
# 1                        Los Angeles International Airport    Los Angeles
# 2                      San Francisco International Airport  San Francisco
# 3                        Los Angeles International Airport    Los Angeles
# 4                     Seattle-Tacoma International Airport        Seattle
# ...                                                    ...            ...
# 5819074                  Los Angeles International Airport    Los Angeles
# 5819075  John F. Kennedy International Airport (New Yor...       New York
# 5819076  John F. Kennedy International Airport (New Yor...       New York
# 5819077                      Orlando International Airport        Orlando
# 5819078  John F. Kennedy International Airport (New Yor...       New York
#
#          STATE  COUNTRY  LATITUDE  LONGITUDE
# 0           AK      USA  61.17432 -149.99619
# 1           CA      USA  33.94254 -118.40807
# 2           CA      USA  37.61900 -122.37484
# 3           CA      USA  33.94254 -118.40807
# 4           WA      USA  47.44898 -122.30931
# ...        ...      ...       ...        ...
# 5819074     CA      USA  33.94254 -118.40807
# 5819075     NY      USA  40.63975  -73.77893
# 5819076     NY      USA  40.63975  -73.77893
# 5819077     FL      USA  28.42889  -81.31603
# 5819078     NY      USA  40.63975  -73.77893
#
# [5819079 rows x 40 columns]
